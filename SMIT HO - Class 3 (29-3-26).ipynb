# %%
print
data types
str
int
float
bool (True , False)
seperator
line break
quuotes

# %% [markdown]
# # varibale
#      - countainer
#      - store data

# %%
course = "Ai and Data Sceince"
# a string values is assinged to a varibale course

# %%
print(course)
# Out:
# Ai and Data Sceince

# %%
marks = 50

# %%
print(marks)
# Out:
# 50

# %%
float_value = 3.45

# %%
print(float_value)
# Out:
# 3.45

# %%
type(float_value)
# Out:
# float

# %% [markdown]
# # llegal aur illegal variables
#       - varibles ko number sai represent ni kr skty start  mai
#             1stpassenger = "larkana" ---> error
#
#
#       - hum log space ni de skte varibales mai
#             first name = "Ali"    ---> error
#
#
#      - special character use ni kr skte
#             @######*= "special characher" ---> error
#
#     - Reserved Word cannot be used in varibae name

# %% [markdown]
# ![image.png](attachment:79c43c2e-2260-44f0-92f6-72fe051ef750.png)![image.png](attachment:b7e7262e-5976-41d3-ba10-0e05875f7a9f.png)

# %% [markdown]
# ![image.png](attachment:bb30d8bc-839c-4d3a-a847-3b0e029fa186.png)![image.png](attachment:6e3f20c2-4a2f-4640-8842-48a31385ea69.png)

# %%
12passenger = "karachi"
# Out:
#   Cell In[15], line 1
#     12passenger = "karachi"
#      ^
# SyntaxError: invalid decimal literal

# %%
passen12ger23 = "karachi"
print(passen12ger23)
# Out:
# karachi

# %%
first name = "ALi"
# Out:
#   Cell In[22], line 1
#     first name = "ALi"
#           ^
# SyntaxError: invalid syntax

# %%
first_name = "hamza"

# %%
print(first_name)
# Out:
# hamza

# %%
a@li = "kamrab"
# Out:
#   Cell In[24], line 1
#     a@li = "kamrab"
#     ^
# SyntaxError: cannot assign to expression here. Maybe you meant '==' instead of '='?

# %%
await= "man"
# Out:
#   Cell In[27], line 1
#     await= "man"
#          ^
# SyntaxError: invalid syntax

# %%
Del = "mano"

# %%
False  = "false"
# Out:
#   Cell In[31], line 1
#     False  = "false"
#     ^
# SyntaxError: cannot assign to False

# %%
print("ai and data science")
# Out:
# ai and data science

# %%
corse  = "ai and data science"

# %%
corse
# Out:
# 'ai and data science'

# %% [markdown]
# # Operators
#      - Arithmetic Operator
#        - Addition (+)
#        - Subtartion (-)
#        - multiplication (*)
#        - Exponent (**)
#        - Divison
#            - float Devsion(/)
#            - florr Devision(//)
#        - Modulus (%)
#     - Relational / Comparison Operator
#        - Double Equal to (==)
#        - Not Equal to(!=)
#        - Greater then(>)
#        - Less than (<)
#        - Greater than or Equal to (>=)
#        - Less the or Equal to (<=)
#     - Logical Operator
#       - Logical And
#       - Logical OR
#       - Logical Not
#
#     - Operator precedence
#          - PEMDAS
#
#     - increment or decrement operator

# %%
100+300
# Out:
# 400

# %%
400-348
# Out:
# 52

# %%
500-289
# Out:
# 211

# %%
2*4
# Out:
# 8

# %%
2*9
# Out:
# 18

# %%
10/2 # float devision
# Out:
# 5.0

# %%
10//2  # florr devision
# Out:
# 5

# %%
15/7 # float
# Out:
# 2.142857142857143

# %%
15//7  # florr devison
# Out:
# 2

# %%
2**3 # exponent (2 *2*2)
# Out:
# 8

# %%
3**4    # 3*3*3*3
# Out:
# 81

# %%
729*9
# Out:
# 6561

# %%
9**4  # 9*9*9*9
# Out:
# 6561

# %%
15%7  # modulos operator
# Out:
# 1

# %%
23%3
# Out:
# 2

# %% [markdown]
# # Relational / Comparison Operator

# %%
100>200  # return in boolean
# Out:
# False

# %%
200>134
# Out:
# True

# %%
20>6  #  grether than
# Out:
# True

# %%
200<150 # less then
# Out:
# False

# %%
print(900 == 700)  # double equal to
print(700 == 700)
# Out:
# False
# True

# %%
600 == 600
# Out:
# True

# %%
400 != 300
# Out:
# True

# %%
200>=200  # dono numvber same hon
# Out:
# True

# %%
600<=600
# Out:
# True

# %%
300 >= 300
# Out:
# True

# %%
200<=200    # single condotion
# Out:
# True

# %% [markdown]
# # Logica operator
#     - more then one condition
#     - AND
#     - OR
#     -NOt

# %% [raw]
# OR operator:
#             or operator aik bhi bat sachi ho agye sb ko True kr den ga
# True (or) False = True
# True (or) True = True
# False (or) True = True
# False (or) False = False

# %% [raw]
# And operator
#             and operator kehta hai agar condition mai aik bhi bat
# jhoti / galat ho gaye to sare galat krde ga
#
# True and True = True
# True and False = False
# False and True = False
# False and False = False

# %%
a = 10
b = 20
c = 30

# %%
# or operator example

# %%
(a>b) or (b>a) or (c<a)
 #F        T        F
# Out:
# True

# %%
# and operator example

# %%
a = 10
b = 20
c = 30

# %%
(a>b) and (b>a) and (c<a)
# f        T         f
# Out:
# False

# %%
amir = 900
bilal = 400
cacha = 1000

# %%
(cacha>bilal) or (amir > bilal) or (cacha<amir)
  #T                   T                F
# Out:
# True

# %%
amir = 900
bilal = 400
cacha = 1000

# %%
(cacha>bilal) and (amir > bilal) and (cacha>amir)
  # T                 T               T
# Out:
# True

# %%
(1.1+2.2) == 3.3
# Out:
# False

# %%
a = 1.1+2.2
b = 3.3
print(a)
# Out:
# 3.3000000000000003

# %%
x = 10.0
y = (x < 100.0) and isinstance(x,int)
print(y)
# Out:
# False

# %%
y
# Out:
# False

# %%
a = 23
isinstance(a,int)
# Out:
# True
