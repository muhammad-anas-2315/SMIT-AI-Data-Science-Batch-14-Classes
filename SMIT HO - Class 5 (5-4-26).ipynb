# %% [markdown]
# # string function
# jb mai string ki bat kro to string (immutable) (chnage ni ho skti) they can be chnaged  in memory

# %%
course = "ai and data science"

# %%
course_2 = course.capitalize()

# %%
print(course)
print(course_2)
# Out:
# ai and data science
# Ai and data science

# %%
course.upper()
# Out:
# 'AI AND DATA SCIENCE'

# %%
course.lower()
# Out:
# 'ai and data science'

# %%
course.casefold()
# Out:
# 'ai and data science'

# %%
course.count("a")
# Out:
# 4

# %%
course.count(" ")
# Out:
# 3

# %%
text = """
Artificial Intelligence (AI) and data science are interconnected, rapidly growing fields transforming industries by utilizing data to improve algorithms and automate complex tasks. While data science focuses on analyzing data for insights and predictions, AI acts on that data to enable autonomous
machine decision-making, with machine learning often acting as the bridge between both disciplines"""

# %%
text.count(" ")
# Out:
# 53

# %%
course.find("s",0)
# Out:
# 12

# %%
ai and data science

# %%
course.endswith("a") # return answere in bool
# Out:
# False

# %%
course.endswith("e")
# Out:
# True

# %%
course.startswith("i")
# Out:
# False

# %%
course.isdigit()
# Out:
# False

# %%
course.replace("and","622")
# Out:
# 'ai 622 data science'

# %%
course.capitalize()
# Out:
# 'Ai and data science'

# %%
course.upper()
# Out:
# 'AI AND DATA SCIENCE'

# %%
text.title()
# Out:
# '\nArtificial Intelligence (Ai) And Data Science Are Interconnected, Rapidly Growing Fields Transforming Industries By Utilizing Data To Improve Algorithms And Automate Complex Tasks. While Data Science Focuses On Analyzing Data For Insights And Predictions, Ai Acts On That Data To Enable Autonomous\nMachine Decision-Making, With Machine Learning Often Acting As The Bridge Between Both Disciplines'

# %%
"".join(text)
# Out:
# '\nArtificial Intelligence (AI) and data science are interconnected, rapidly growing fields transforming industries by utilizing data to improve algorithms and automate complex tasks. While data science focuses on analyzing data for insights and predictions, AI acts on that data to enable autonomous\nmachine decision-making, with machine learning often acting as the bridge between both disciplines'

# %%
text= """Muhammad Ali Jinnah[a] (born Mahomedali Jinnahbhai;[b] 25 December 1876 – 11 September 1948) was a barrister, politician, and the founder of Pakistan. Jinnah served as the leader of the All-India Muslim League from 1913 until the inception of Pakistan on 14 August 1947 and then as Pakistan's first governor-general until his death a year later in 1948.Born at Wazir Mansion in"""

# %%
"".join(text)
# Out:
# "Muhammad Ali Jinnah[a] (born Mahomedali Jinnahbhai;[b] 25 December 1876 – 11 September 1948) was a barrister, politician, and the founder of Pakistan. Jinnah served as the leader of the All-India Muslim League from 1913 until the inception of Pakistan on 14 August 1947 and then as Pakistan's first governor-general until his death a year later in 1948.Born at Wazir Mansion in"

# %% [markdown]
# # Type casting
#                aik data type sai dosri data type mai convert krna
#
#          most comman type cating
#         -  int() = convert into int type
#         -  str() = convert into str type
#         - float() = convert into float type
#         - Bool() = convert into bool type

# %%
a = "hello"

# %%
type(a)
# Out:
# str

# %%
b = '23'

# %%
type(b)
# Out:
# str

# %%
int(b)
# Out:
# 23

# %%
age = "seventy six"
# Out:
# '23'

# %%
str("hello")
# Out:
# 'hello'

# %%
d = 9.08

# %%
int(d)
# Out:
# 9

# %% [markdown]
# # user input

# %%
name = input("Enter your name")
age = input("Enter your age")

print(name)
print(age)

print(type(name))
print(type(age))
# Out:
# Enter your name usman
# Enter your age 22
# usman
# 22
# <class 'str'>
# <class 'str'>

# %%
name = input("Enter your name")
age = int(input("Enter your age"))

print(name)
print(age)

print(type(name))
print(type(age))
# Out:
# Enter your name usman
# Enter your age 22
# usman
# 22
# <class 'str'>
# <class 'int'>

# %%
name = input("Enter your name")
age = int(input("Enter your age"))


print(name)
print(age)

print(type(name))
print(type(age))
# Out:
# Enter your name usman
# Enter your age 4
# usman
# 4
# <class 'str'>
# <class 'int'>

# %%
a = "5"

# %%
int(a)
# Out:
# 5

# %%
a = "8.9999"

# %%
int(float(a))
# Out:
# 8

# %% [markdown]
# # string concatination

# %%
first_name = "usman"
secound_name = "shah"

# %%
first_name+secound_name
# Out:
# 'usmanshah'

# %%
name = input("Enter your name")
age = input("Enter your name")

# print("your name  is usman, your age is 56")
print("your name  is",name, "your age is ",age)
# Out:
# Enter your name ali
# Enter your name 34
# your name  is ali your age is  34

# %% [markdown]
# # format function

# %%
name = input("Enter your name")
age = input("Enter your name")
# {} place holder = hold krna
print("your name is {}, your age is {}".format(name,age))
# Out:
# Enter your name usman
# Enter your name 4
# your name is usman, your age is 4

# %% [markdown]
# # f string/

# %%
name = input("Enter your name")
age = input("Enter your name")
# {} place holder = hold krna
answere = f"your name is {name} , your age is {age}"
print(answere)
# Out:
# Enter your name ali
# Enter your name 23
# your name is ali , your age is 23

# %%
name = input("ENter your name: ")
father_name = input("Enter your father_name :")
Roll_num = int(input("ENter your Roll_num :"))
course = input("ENter your Course :")
institute = input("Enter youyr institute: ")
branch = input("Enter your Branch: ")

print(f"""
            Student ID Card
            ======================
        Name : {name},
        fahter_name : {father_name},
        Roll_no : {Roll_num},
        course : {course},
        institue : {institute},
        branch : {branch},
        
        
        Note : SMIT (Saylnai mass it traning)
    """)
# Out:
# ENter your name:  ALi
# Enter your father_name Abdullah
# ENter your Roll_num 106578
# ENter your Course AI and Data Scinece
# Enter youyr institute SMIT
# Enter your Branch HEAD OFFICE
#             Student ID Card
# ...
#         Name : ALi,
#         fahter_name : Abdullah,
#         Roll_no : 106578,
#         course : AI and Data Scinece,
#         institue : SMIT,
#         branch : HEAD OFFICE,
#
#
#         Note : SMIT (Saylnai mass it traning)
