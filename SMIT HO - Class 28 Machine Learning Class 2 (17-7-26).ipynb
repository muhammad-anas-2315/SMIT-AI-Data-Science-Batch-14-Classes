# %%
import pandas as pd

# %%
data =pd.read_csv("weight-height.csv")

# %%
data
# Out:
#       Gender     Height      Weight
# 0       Male  73.847017  241.893563
# 1       Male  68.781904  162.310473
# 2       Male  74.110105  212.740856
# 3       Male  71.730978  220.042470
# 4       Male  69.881796  206.349801
# ...      ...        ...         ...
# 9995  Female  66.172652  136.777454
# 9996  Female  67.067155  170.867906
# 9997  Female  63.867992  128.475319
# 9998  Female  69.034243  163.852461
# 9999  Female  61.944246  113.649103
#
# [10000 rows x 3 columns]

# %%
  regression:
              linear regression:    when we predict the numerical values
              1)simple linear regression ( one input features hon)

# %%
x = data[["Height"]]
y  = data[["Weight"]]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(x,y,test_size=0.30 ,
                                                    random_state=42)

# %%
print(X_train.shape)
print(X_test.shape)
# Out:
# (7000, 1)
# (3000, 1)

# %%
print(y_train.shape)
print(y_test.shape)
# Out:
# (7000, 1)
# (3000, 1)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = lr.predict(X_train)

# %%
lr.intercept_
# Out:
# array([-349.3233486])

# %%
lr.coef_
# Out:
# array([[7.69542535]])

# %%
import matplotlib.pyplot as plt
data.plot(kind='scatter', x='Height', y='Weight',
       title='Weight and Height in adults')

plt.plot(X_train,y_pred, color='red', linewidth=3)
plt.show()

# %%
best fit line

# %%
from sklearn.metrics import r2_score, mean_absolute_error

# %%
r2_score(y_train,y_pred)
# Out:
# 0.8539725668335597

# %%
mean_absolute_error(y_train,y_pred)
# Out:
# 9.763588430590442

# %%
 y_pred_test = lr.predict(X_test)

# %%
r2_score(y_test,y_pred_test)
# Out:
# 0.8577298529572459

# %%
mean_absolute_error(y_test,y_pred_test)
# Out:
# 9.709435606344526

# %%
def pred_weight(h):
  return lr.predict([[h]])/0.453592

# %%
height= float(input("Ente4 a height in feet"))*12
pred_weight(height)
# Out:
# Ente4 a height in feet7.8
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[817.84613589]])
