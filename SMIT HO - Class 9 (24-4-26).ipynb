# %%
shop = ["calculator","pen","notebook","special_book","shopner"]

# %%
type(shop)
# Out:
# list

# %%
len(shop)
# Out:
# 5

# %%
shop.pop(2)
# Out:
# 'shopner'

# %%
shop.sort()

# %% [markdown]
# ![image.png](attachment:00faa319-15ae-405f-af14-6fd252da0fdb.png)

# %%
shop.reverse()

# %%
shop
# Out:
# ['special_book', 'pen', 'notebook', 'calculator']

# %%
shop.remove("pen")

# %%
shop
# Out:
# ['special_book', 'notebook', 'calculator']

# %% [markdown]
# # copy by reference

# %%
a  = [1,2,3,4,5]
b = a
c = 22

# %%
id(a)
# Out:
# 2267977667072

# %%
id(b)
# Out:
# 2267977667072

# %%
id(c)
# Out:
# 140707492374088

# %%
a
# Out:
# [1, 2, 3, 4, 5]

# %%
b
# Out:
# [1, 2, 3, 4, 5]

# %% [markdown]
# # list in a list

# %%
alist = [1,2,3,4,[5000,6000,7000,8000]]

# %%
alist[2][4]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 alist[2][4]
#
# TypeError: 'int' object is not subscriptable

# %%
alist[4:][0][1]
# Out:
# 6000

# %%
["man",78,7.8,True]
# Out:
# ['man', 78, 7.8, True]

# %% [markdown]
# # Tuple
#       - declaration (22,)
#       - can hold any data type
#       - imuutable
#       - list sai fast hoti hai

# %%
atuple = 12 , 12, 33

# %%
type(atuple)
# Out:
# tuple

# %%
atuple = ("ALi","kamran",89,6.7,True)

# %%
type(atuple)
# Out:
# tuple

# %%
atuple[1]
# Out:
# 'kamran'

# %%
atuple.

# %% [markdown]
# # Dictonary
#     -  {}
#     - key value pairs
#     - mutable
#     - loop

# %%
empty_dict = {}
print(type(empty_dict))
# Out:
# <class 'dict'>

# %%
menu = {"biryani":200, "Pizza":900,"tikka_boti":250}

# %%
menu["Pizza"]
# Out:
# 900

# %%
menu["biryani"] = 400

# %%
menu["Pizza"]
# Out:
# 500

# %%
menu["fires"]
# Out:
# 50

# %%
ctrl+shift+h

# %%
menu['Amount'] = "tum mat do"
       # key        value

# %%
["usman",12,"male",34,"+++"]
# Out:
# ['usman', 12, 'male', 34, '+++']

# %%
info = {'name':'ALi',"age":19,"gender":"male","weight":"20kg"}

# %%
info["age"]
# Out:
# 19

# %%
info["age"] = 25

# %%
info
# Out:
# {'name': 'ALi', 'age': 25, 'gender': 'male', 'weight': '20kg'}

# %%
info.get("age")
# Out:
# 25

# %%
info.keys()
# Out:
# dict_keys(['name', 'age', 'gender', 'weight'])

# %%
info.values()
# Out:
# dict_values(['ALi', 25, 'male', '20kg'])

# %%
info.items()
# Out:
# dict_items([('name', 'ALi'), ('age', 25), ('gender', 'male'), ('weight', '20kg')])

# %%
info.popitem()
# Out:
# ('weight', '20kg')

# %%
info
# Out:
# {'name': 'ALi', 'age': 25, 'gender': 'male'}

# %%
list 
tuple
dict
set

# %% [markdown]
# # sets
#     {}  --->
#     - orderd
#     - immutable
#     - duplicate value ni rkhta

# %%
sets = {"nano",1,2,2,4,5,6,"man","mano"}
print(type(sets))
print(sets)
# Out:
# <class 'set'>
# {1, 2, 4, 5, 6, 'nano', 'mano', 'man'}

# %% [markdown]
# # combine kr dia union nai

# %%
a = {1,2,3,4,5}   # (4,5)
b = {4,5,6,7,8}
a.union(b)
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8}

# %% [markdown]
# # intersaction mai jo comman ho ga wo aye ga

# %%
a.intersection(b)
# Out:
# {4, 5}
