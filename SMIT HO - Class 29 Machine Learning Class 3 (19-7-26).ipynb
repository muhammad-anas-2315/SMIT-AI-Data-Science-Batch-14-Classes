# %%
import pandas as pd

# %%
data = pd.read_csv("weight-height.csv")

# %%
data.head()
# Out:
#   Gender     Height      Weight
# 0   Male  73.847017  241.893563
# 1   Male  68.781904  162.310473
# 2   Male  74.110105  212.740856
# 3   Male  71.730978  220.042470
# 4   Male  69.881796  206.349801

# %% [markdown]
# ## X,y

# %%
x = data[["Height"]]
y = data[["Weight"]]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(x,y, test_size=0.25, random_state=42)

# %%
X_train
# Out:
#          Height
# 4901  64.276493
# 4375  72.923970
# 6698  66.382870
# 9805  64.174279
# 1101  71.859849
# ...         ...
# 5734  63.349988
# 5191  58.861625
# 5390  64.325406
# 860   69.074492
# 7270  67.588840
#
# [7500 rows x 1 columns]

# %% [markdown]
# ### Model traning

# %%
from sklearn.linear_model import LinearRegression

# %%
model  = LinearRegression()

# %%
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X_train)

# %% [raw]
# 1) acuuracy
# 2) lose

# %% [markdown]
# ### Training data

# %%
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error

# %%
r2_score(y_train, y_pred)*100   # accuracy
# Out:
# 85.43986528206867

# %%
mean_absolute_error(y_train, y_pred)  # lose
# Out:
# 9.755565351821717

# %% [markdown]
# ### Testing Data

# %%
y_test_pred = model.predict(X_test)

# %%
r2_score(y_test, y_test_pred)*100  # accuracy
# Out:
# 85.73532042714066

# %%
mean_absolute_error(y_test, y_test_pred)  # lose
# Out:
# 9.720990894150075

# %% [markdown]
# ### overfitting:
#             Differnec (Gap) between Trainig and Testing Acccuracy
#
# ### underfit: performance low on training data    perfromace low on testing data
# ### overfit:  performance high on traning data    perfromance low on testing data
# ### Bestfit:  performancce high on training data  performance high on testing data

# %% [markdown]
# ![image.png](attachment:a75059c7-4519-46d3-9376-904fee9d1397.png)

# %% [markdown]
# ### prediction

# %%
def wight_prediction(height):
    return model.predict([[height]])*0.453592

# %%
heightt = float(input("Enter you height in ft"))*12
wight_prediction(heightt)
# Out:
# Enter you height in ft 5.6
# C:\Users\Teacher PC\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[76.10839516]])

# %%
data
# Out:
#       Gender     Height      Weight
# 0       Male  73.847017  241.893563
# 1       Male  68.781904  162.310473
# 2       Male  74.110105  212.740856
# 3       Male  71.730978  220.042470
# 4       Male  69.881796  206.349801
# ...      ...        ...         ...
# 9995  Female  66.172652  136.777454
# 9996  Female  67.067155  170.867906
# 9997  Female  63.867992  128.475319
# 9998  Female  69.034243  163.852461
# 9999  Female  61.944246  113.649103
#
# [10000 rows x 3 columns]
