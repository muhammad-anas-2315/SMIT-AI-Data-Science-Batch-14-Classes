# %%
# print is a python function

# %%
print("Hello python")
# Out:
# Hello python

# %%
shift + ""

# %%
shift + enter
control + enter

# %%
print("12336736374")
# Out:
# 12336736374

# %%
escp+1

# %% [markdown]
# # Type

# %% [markdown]
# data = Values
#
# values = Text = "I am a doctor" > string > str
#
# integer number:
#               whole number > integer > int  = [1,2,3,,4,,5,,5,6,........]
#               decimal number > float > float =[1.0,2.0,3.999,0.999.........]
#
# boolean = True/False
#
# text ya sentence '',"",""""  -> str

# %% [markdown]
# # string

# %%
print("Usman")
# Out:
# Usman

# %%
print(type("hello"))
# Out:
# <class 'str'>

# %%
print(type("123"))
# Out:
# <class 'str'>

# %%
print(type("9.085"))
# Out:
# <class 'str'>

# %% [markdown]
# # int

# %%
print(type(89))
# Out:
# <class 'int'>

# %%
print(type(3763735))
# Out:
# <class 'int'>

# %% [markdown]
# # float

# %%
print(type(1.207))
# Out:
# <class 'float'>

# %%
print(type("89"))  # -> str
print(type("hllo")) #-> str
print(type(9)) # -> int
print(type(1.207))# -> float
print(type(True))
print(type(False))
# Out:
# <class 'str'>
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'bool'>
# <class 'bool'>

# %% [markdown]
# ### single quote
# ### double quote
# ### tripel quote

# %% [markdown]
# # single quote

# %%
print('hello python')
print('ai and data science')
print('friday day')
# Out:
# hello python
# ai and data science
# friday day

# %%
print("ai")
# Out:
# ai

# %% [markdown]
# #  double quote

# %%
print("hello python")
print("ai and data science")
print('friday day')
# Out:
# hello python
# ai and data science
# friday day

# %%
print('''hb
hubueb
      hfuebeuf
      feyubelbfe
      vfeufbe
      bfeube''')
# Out:
# hb
# hubueb
#       hfuebeuf
#       feyubelbfe
#       vfeufbe
#       bfeube

# %% [markdown]
# # trible quote

# %%
shift + "" = ""

# %%
print('''hello world''')
# Out:
# hello world

# %%
print('''my name  is usman
my frinetd name is furqan
prime minister 
imran khan
''')
# Out:
# my name  is usman
# my frinetd name is furqan
# prime minister
# imran khan

# %%
print('''
secound "class" 
"friday"
''')
# Out:
# secound "class"
# "friday"

# %%
print("hello"          ,                                 "world                             best")
# Out:
# hello world                             best

# %%
print('''hello
world''')
# Out:
# hello
# world

# %% [markdown]
# # \n move to the next line

# %%
print("hello\n""world\n""python""\n""pythpo")
# Out:
# hello
# world
# python
# pythpo

# %%
print("hello",90)
# Out:
# hello 90

# %%
# shift + tab -> funstion bio

# %%
print("python,","developer","hllo",12, 7.97484,True,sep=" - ")
# Out:
# python, - developer - hllo - 12 - 7.97484 - True

# %%
print("python","developer",sep = "566")
# Out:
# pythondeveloper

# %%
print("""
Artificial Intelligence (AI) 
and Data Science are closely related,
high-growth fields driving modern technology, 
with AI focusing on building intelligent systems
that act autonomously, while Data Science extracts
insights from data to guide decisions. AI creates systems
(like chatbots) using machine learning, whereas data science 
analyzes past trends to predict future ones""")
# Out:
# Artificial Intelligence (AI)
# and Data Science are closely related,
# high-growth fields driving modern technology,
# with AI focusing on building intelligent systems
# that act autonomously, while Data Science extracts
# insights from data to guide decisions. AI creates systems
# (like chatbots) using machine learning, whereas data science
# analyzes past trends to predict future ones

# %%
print("Artificial Intelligence (AI)\n and Data Science are closely\n related, high-growth fields driving modern technology, with AI\n focusing on building intelligent systems that act \nautonomously, while Data Science extracts insights from\n data to guide decisions. AI creates systems (like chatbots) using\n machine learning, whereas data\n science analyzes past trends to predict future ones. ")
# Out:
# Artificial Intelligence (AI)
#  and Data Science are closely
#  related, high-growth fields driving modern technology, with AI
#  focusing on building intelligent systems that act
# autonomously, while Data Science extracts insights from
#  data to guide decisions. AI creates systems (like chatbots) using
#  machine learning, whereas data
#  science analyzes past trends to predict future ones.

# %%
Artificial Intelligence (AI)
and Data Science are closely

# %%
: colon
; terminator/semicolon
() parenthesis
- hyphen

# %%
print('''name:
   "usman",.9''')
# Out:
# name:
#    "usman",.9

# %% [raw]
# name:
#       "usman". 9

# %%
print('name:\n\n "usman".9',9)
# Out:
# name:
#
#  "usman".9 9
