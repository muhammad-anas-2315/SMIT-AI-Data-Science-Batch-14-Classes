# %% [markdown]
# # console input

# %%
num = int(input("ENter a number:"))
print(f"the dounle of the number is {num*2}")
# Out:
# ENter a number: 2
# the dounle of the number is 4

# %% [markdown]
# # Conditional Statement
#         - if statement  (if keyword   :   statement : conditions )
#         - if clause

# %%
a = 10
if a < 5:
    print("A is greather then 5")
    print("A is greather then 5")
    print("A is greather then 5")

# %%
a =20
if a % 2==0 :
    print("Even number")
else:
    print("odd number")
# Out:
# Even number

# %%
age = int(input("ENter a age"))
if age>=18:
    print("job kai liye apply kr skte")
    print("cnic bn skta hai ")
    print("license bn skta hai")
    print("Nikkah kr skte hai")
else:
    print("pogo dekho")
    print("dahi lai kr ao")
# Out:
# ENter a age 12
# pogo dekho
# dahi lai kr ao

# %%
a = int(input("ENter a number"))
if a % 2==0 :
    print("Even number",a, sep = "-")
else:
    print("odd number",a, sep = "-")
# Out:
# ENter a number 22
# Even number-22

# %%
a = int(input("ENter a number"))
if a % 2==0 :
    print(f"Even number  {a}") {} place holder
else:
    print(f"odd number {a}")
# Out:
# ENter a number 34
# Even number  34

# %%
battery = int(input("ENter a number"))
if battery >= 10:
    print("Reels dekho")
else:
    print("charege krlo")
# Out:
# ENter a number 2333333
# Reels dekho

# %%
10 sai zyada ho (reels enjoy kro)
10 sai kam hon (charge kr lo)

# %%
html= int(input("Enter a number:  "))
python = int(input("Enter a number: "))
jawa = int(input("Enter a number: "))
php = int(input("Enter a number: "))
egg  = int(input("ENter a number :  "))
total = html+python+jawa+php+egg

# condition
if total>400:
    print(f"your are pass in exam and obtain matks {total}")
else:
    print(f"Better luck next time : Fail {total} ")
# Out:
# Enter a number:   90
# Enter a number:  90
# Enter a number:  90
# Enter a number:  90
# ENter a number :   90
# your are pass in exam and obtain matks 450

# %%
int =- 83738337883737673

# %%
signal_light_color = input("color btao").lower()
if signal_light_color=="red": 
    print("ruk jao")
else:
    print("jate rho")
# Out:
# color btao r     e   d
# jate rho

# %%
"hello".capitalize()  # First letter ko capital
# Out:
# 'Hello'

# %%
"hello and world".title()
# Out:
# 'Hello And World'

# %%
name= "usman"
name.upper()
# Out:
# 'USMAN'

# %%
=  "assine krna"
name = "hello"

# %%
if name == name:
    pri

# %%
"hellio".
